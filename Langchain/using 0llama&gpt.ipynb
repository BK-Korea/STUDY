# %%
# %pip install -q langchain-ollama langchain-openai
# %pip install langchain-openai python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.getcwd())
# Out:
# /Users/bk/langchain-basics

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()

# API 키 확인
api_key = os.getenv("OPENAI_API_KEY")
if api_key and api_key.startswith("sk-"):
    print(f"✅ API 키 로드 성공: {api_key[:20]}...")
else:
    print("❌ API 키가 없거나 잘못되었습니다!")
    print(f"현재 값: {api_key}")
# Out:
# ✅ API 키 로드 성공: sk-proj-NBtRNs6qnCYx...

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2")
llm.invoke("what is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-11-05T10:44:59.174425Z', 'done': True, 'done_reason': 'stop', 'total_duration': 299029084, 'load_duration': 101600125, 'prompt_eval_count': 32, 'prompt_eval_duration': 81422750, 'eval_count': 8, 'eval_duration': 110716041, 'model_name': 'llama3.2'}, id='run--a4675a10-fe79-49fa-a7f5-ab0ef08fe9aa-0', usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
# %pip install --upgrade pip
# %pip install -q langchain-openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

try:
    print("🔄 ChatOpenAI 초기화 중...")
    llm = ChatOpenAI(model="gpt-4o-mini")
    print("✅ ChatOpenAI 초기화 성공")
    
    print("\n🔄 API 호출 중...")
    response = llm.invoke("what is the capital of France?")
    print(f"✅ 응답: {response}")
except Exception as e:
    print(f"❌ 에러 발생: {type(e).__name__}")
    print(f"메시지: {str(e)[:200]}")
# Out:
# 🔄 ChatOpenAI 초기화 중...
# ✅ ChatOpenAI 초기화 성공
#
# 🔄 API 호출 중...
# ✅ 응답: content='The capital of France is Paris.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 14, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_51db84afab', 'id': 'chatcmpl-CYVIb52Pgf7dE7hTaXM8fDvOLcR9L', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--a81144d5-2d24-4a48-a94e-a7387d9232f7-0' usage_metadata={'input_tokens': 14, 'output_tokens': 7, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Azure OpenAI example (requires Azure credentials)
# from langchain_openai import AzureOpenAI
# llm = AzureOpenAI(
#     model="gpt-4o-mini",
#     azure_endpoint="https://<your-resource>.openai.azure.com/",
#     api_key="<your-api-key>"
# )
# llm.invoke("what is the capital of France?")
